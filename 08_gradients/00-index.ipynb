# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 8: Gradients
#
# 1. [The Gradient Vector](01-gradient-vector.ipynb)
# 2. [Gradients of Matrix-Vector Operations](02-gradients-matrix-vector-operations.ipynb)
# 3. [Gradient Descent](03-gradient-descent.ipynb)
# 4. [Gradient Descent for Empirical Risk Minimization](04-gradient-descent-erm.ipynb)
# 5. [Convexity](05-convexity.ipynb)
