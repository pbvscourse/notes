# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 2: Multispectral and Hyperspectral
#
# 1. [Vectors and Linear Combinations](01-vectors-and-linear-combinations.ipynb)
# 2. [Norms](02-norms.ipynb)
# 3. [The Dot Product](03-dot-product.ipynb)
# 4. [Projecting onto a Single Vector](04-projecting-onto-a-single-vector.ipynb)
