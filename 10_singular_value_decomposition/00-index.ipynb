# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 10: Singular Value Decomposition
#
# 1. [Computing the Singular Value Decomposition](01-computing-svd.ipynb)
# 2. [Low-Rank Approximation](02-low-rank-approximation.ipynb)
# 3. [The Best Direction](03-best-direction.ipynb)
# 4. [Principal Components Analysis](04-principal-components-analysis.ipynb)
# 5. [Looking Forward](05-looking-forward.ipynb)
