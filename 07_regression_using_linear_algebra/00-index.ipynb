# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 7: Regression using Linear Algebra
#
# 1. [Regression using Linear Algebra](01-regression-using-linear-algebra.ipynb)
# 2. [Multiple Linear Regression](02-multiple-linear-regression.ipynb)
