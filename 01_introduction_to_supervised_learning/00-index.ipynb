# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 1: Introduction to Supervised Learning
#
# 1. [What is Machine Learning?](01-what-is-machine-learning.ipynb)
# 2. [Squared Loss and the Constant Model](02-squared-loss-constant-model.ipynb)
# 3. [Absolute Loss](03-absolute-loss.ipynb)
# 4. [Comparing Loss Functions](04-comparing-loss-functions.ipynb)
