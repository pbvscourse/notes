# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 6: Linear Transformations and Projections
#
# 1. [Linear Transformations](01-linear-transformations.ipynb)
# 2. [Inverses](02-inverses.ipynb)
# 3. [Projecting onto the Column Space](03-projecting-onto-column-space.ipynb)
# 4. [The Complete Solution](04-complete-solution.ipynb)
# 5. [The Gram-Schmidt Process](05-gram-schmidt-process.ipynb)
