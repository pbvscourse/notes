# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 2: Simple Linear Regression
#
# 1. [Overview](01-overview.ipynb)
# 2. [Detour: Partial Derivatives](02-partial-derivatives.ipynb)
# 3. [Finding Optimal Parameters](03-finding-optimal-parameters.ipynb)
# 4. [Correlation](04-correlation.ipynb)
# 5. [Least Squares](05-least-squares.ipynb)
