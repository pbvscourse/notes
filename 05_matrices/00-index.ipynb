# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 5: Matrices
#
# 1. [Matrix Operations](01-matrix-operations.ipynb)
# 2. [Special Matrices](02-special-matrices.ipynb)
# 3. [Rank and Column Space](03-rank-and-column-space.ipynb)
# 4. [Null Space and the Rank-Nullity Theorem](04-null-space-rank-nullity.ipynb)
