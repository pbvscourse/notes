# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 4: Linear Independence
#
# 1. [Span](01-span.ipynb)
# 2. [Linear Independence](02-linear-independence.ipynb)
# 3. [Vector Spaces, Basis, and Dimension](03-vector-spaces-basis-dimension.ipynb)
# 4. [Lines, Planes, and Hyperplanes](04-lines-planes-hyperplanes.ipynb)
