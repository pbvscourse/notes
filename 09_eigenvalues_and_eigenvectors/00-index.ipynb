# %% [markdown]
# ---
# numbering: false
# ---
#
# # Chapter 9: Eigenvalues and Eigenvectors
#
# 1. [Eigenvalues and Eigenvectors](01-eigenvalues-eigenvectors.ipynb)
# 2. [The Characteristic Polynomial](02-characteristic-polynomial.ipynb)
# 3. [Markov Chains and Adjacency Matrices](03-markov-chains-adjacency-matrices.ipynb)
# 4. [Multiplicities and Diagonalization](04-multiplicities-diagonalization.ipynb)
# 5. [Symmetric Matrices and the Spectral Theorem](05-symmetric-matrices-spectral-theorem.ipynb)
# 6. [The Rayleigh Quotient](06-rayleigh-quotient.ipynb)
